# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow tensorflow-gpu opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\winner\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: tensorflow-gpu in c:\users\winner\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: opencv-python in c:\users\winner\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: mediapipe in c:\users\winner\anaconda3\lib\site-packages (0.8.9.1)
# Requirement already satisfied: sklearn in c:\users\winner\anaconda3\lib\site-packages (0.0.post1)
# Requirement already satisfied: matplotlib in c:\users\winner\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\winner\appdata\roaming\python\python39\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: six~=1.15.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\winner\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\winner\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\winner\anaconda3\lib\site-packages (from mediapipe) (4.7.0.68)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\winner\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (63.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\winner\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.28.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\winner\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\winner\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\winner\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\winner\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\winner\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winner\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winner\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\winner\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\winner\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\winner\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.2.2)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose,lh, rh])

# %%
extract_keypoints(results).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11024\1375359374.py in <module>
# ----> 1 extract_keypoints(results).shape
#
# NameError: name 'results' is not defined

# %%
result_test

# %%
np.save('0', result_test)

# %%
np.load('0.npy')

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['A','B','C','D','E','F','G', 'thank you', 'Hello'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 20 frames in length
sequence_length = 20

# Folder start
start_folder = 0

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape

# %%
np.array(labels).shape

# %%
X = np.array(sequences)

# %%
X.shape

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(20,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=150,callbacks=[tb_callback])
# Out:
# Epoch 1/150
# 8/8 [==============================] - 4s 135ms/step - loss: 2.1965 - categorical_accuracy: 0.0938
# Epoch 2/150
# 8/8 [==============================] - 0s 43ms/step - loss: 2.1000 - categorical_accuracy: 0.1680
# Epoch 3/150
# 8/8 [==============================] - 0s 40ms/step - loss: 1.8949 - categorical_accuracy: 0.2852
# Epoch 4/150
# 8/8 [==============================] - 0s 49ms/step - loss: 1.9160 - categorical_accuracy: 0.2266
# Epoch 5/150
# 8/8 [==============================] - 0s 47ms/step - loss: 1.8421 - categorical_accuracy: 0.3477
# Epoch 6/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.7968 - categorical_accuracy: 0.3242
# Epoch 7/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.7017 - categorical_accuracy: 0.3203
# Epoch 8/150
# 8/8 [==============================] - 0s 39ms/step - loss: 1.7467 - categorical_accuracy: 0.3047
# Epoch 9/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.7327 - categorical_accuracy: 0.3555
# Epoch 10/150
# 8/8 [==============================] - 0s 40ms/step - loss: 1.6679 - categorical_accuracy: 0.3320
# Epoch 11/150
# 8/8 [==============================] - 0s 37ms/step - loss: 1.5990 - categorical_accuracy: 0.3750
# Epoch 12/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.6494 - categorical_accuracy: 0.3320
# Epoch 13/150
# 8/8 [==============================] - 0s 37ms/step - loss: 1.6016 - categorical_accuracy: 0.3477
# Epoch 14/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.4792 - categorical_accuracy: 0.3867
# Epoch 15/150
# 8/8 [==============================] - 0s 40ms/step - loss: 1.5527 - categorical_accuracy: 0.4180
# Epoch 16/150
# 8/8 [==============================] - 0s 36ms/step - loss: 1.5436 - categorical_accuracy: 0.3633
# Epoch 17/150
# 8/8 [==============================] - 0s 40ms/step - loss: 1.3867 - categorical_accuracy: 0.4453
# Epoch 18/150
# 8/8 [==============================] - ETA: 0s - loss: 1.3639 - categorical_accuracy: 0.43 - 0s 38ms/step - loss: 1.4168 - categorical_accuracy: 0.4180
# Epoch 19/150
# 8/8 [==============================] - 0s 37ms/step - loss: 1.4097 - categorical_accuracy: 0.4180
# Epoch 20/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.3626 - categorical_accuracy: 0.4414
# Epoch 21/150
# 8/8 [==============================] - 0s 36ms/step - loss: 1.3298 - categorical_accuracy: 0.4023
# Epoch 22/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.3591 - categorical_accuracy: 0.5000
# Epoch 23/150
# 8/8 [==============================] - 0s 38ms/step - loss: 1.3097 - categorical_accuracy: 0.4414
# Epoch 24/150
# 8/8 [==============================] - 0s 44ms/step - loss: 1.2536 - categorical_accuracy: 0.4570
# Epoch 25/150
# 8/8 [==============================] - 0s 40ms/step - loss: 1.2895 - categorical_accuracy: 0.4883
# Epoch 26/150
# 8/8 [==============================] - 1s 51ms/step - loss: 1.1117 - categorical_accuracy: 0.5586
# Epoch 27/150
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0743 - categorical_accuracy: 0.5625
# Epoch 28/150
# 8/8 [==============================] - 0s 47ms/step - loss: 1.1553 - categorical_accuracy: 0.5625
# Epoch 29/150
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9809 - categorical_accuracy: 0.5977
# Epoch 30/150
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9707 - categorical_accuracy: 0.5859
# Epoch 31/150
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0110 - categorical_accuracy: 0.5859
# Epoch 32/150
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9026 - categorical_accuracy: 0.6758
# Epoch 33/150
# 8/8 [==============================] - 0s 43ms/step - loss: 1.0241 - categorical_accuracy: 0.5938
# Epoch 34/150
# 8/8 [==============================] - 0s 43ms/step - loss: 1.0618 - categorical_accuracy: 0.5898
# Epoch 35/150
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9547 - categorical_accuracy: 0.6406
# Epoch 36/150
# 8/8 [==============================] - 0s 54ms/step - loss: 1.0588 - categorical_accuracy: 0.5508
# Epoch 37/150
# 8/8 [==============================] - 0s 45ms/step - loss: 1.0371 - categorical_accuracy: 0.5781
# Epoch 38/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.8927 - categorical_accuracy: 0.6406
# Epoch 39/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.8281 - categorical_accuracy: 0.6328
# Epoch 40/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.8445 - categorical_accuracy: 0.6758
# Epoch 41/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.8699 - categorical_accuracy: 0.6602
# Epoch 42/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.7455 - categorical_accuracy: 0.7109
# Epoch 43/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6563 - categorical_accuracy: 0.7695
# Epoch 44/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.7271 - categorical_accuracy: 0.7070
# Epoch 45/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.6445 - categorical_accuracy: 0.7539
# Epoch 46/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.5634 - categorical_accuracy: 0.8047
# Epoch 47/150
# 8/8 [==============================] - 0s 49ms/step - loss: 1.0605 - categorical_accuracy: 0.6367 0s - loss: 0.6943 - categorical_accuracy
# Epoch 48/150
# 8/8 [==============================] - 0s 43ms/step - loss: 1.1523 - categorical_accuracy: 0.5352
# Epoch 49/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.9940 - categorical_accuracy: 0.6445
# Epoch 50/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.8101 - categorical_accuracy: 0.6719
# Epoch 51/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6644 - categorical_accuracy: 0.7578
# Epoch 52/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.6181 - categorical_accuracy: 0.7422
# Epoch 53/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.8696 - categorical_accuracy: 0.6719
# Epoch 54/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7964 - categorical_accuracy: 0.6992
# Epoch 55/150
# 8/8 [==============================] - 0s 52ms/step - loss: 0.6555 - categorical_accuracy: 0.7539
# Epoch 56/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.6089 - categorical_accuracy: 0.7773
# Epoch 57/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5820 - categorical_accuracy: 0.7891
# Epoch 58/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5956 - categorical_accuracy: 0.7656
# Epoch 59/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5783 - categorical_accuracy: 0.7617
# Epoch 60/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.5223 - categorical_accuracy: 0.8008
# Epoch 61/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4578 - categorical_accuracy: 0.8359
# Epoch 62/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5594 - categorical_accuracy: 0.7930
# Epoch 63/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.6316 - categorical_accuracy: 0.7656
# Epoch 64/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5846 - categorical_accuracy: 0.7695
# Epoch 65/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.6934 - categorical_accuracy: 0.7617
# Epoch 66/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6226 - categorical_accuracy: 0.7422
# Epoch 67/150
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4915 - categorical_accuracy: 0.8086
# Epoch 68/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4258 - categorical_accuracy: 0.8203
# Epoch 69/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3767 - categorical_accuracy: 0.8594
# Epoch 70/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3247 - categorical_accuracy: 0.8711
# Epoch 71/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3520 - categorical_accuracy: 0.8594
# Epoch 72/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3247 - categorical_accuracy: 0.8672
# Epoch 73/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3231 - categorical_accuracy: 0.8633
# Epoch 74/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3974 - categorical_accuracy: 0.8125
# Epoch 75/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3557 - categorical_accuracy: 0.8633
# Epoch 76/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2817 - categorical_accuracy: 0.8984
# Epoch 77/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2792 - categorical_accuracy: 0.8867
# Epoch 78/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5505 - categorical_accuracy: 0.8281
# Epoch 79/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.6103 - categorical_accuracy: 0.7773
# Epoch 80/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5053 - categorical_accuracy: 0.8359
# Epoch 81/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3650 - categorical_accuracy: 0.8438
# Epoch 82/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4094 - categorical_accuracy: 0.8398
# Epoch 83/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3103 - categorical_accuracy: 0.8828
# Epoch 84/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3951 - categorical_accuracy: 0.8477
# Epoch 85/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4316 - categorical_accuracy: 0.8516
# Epoch 86/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3005 - categorical_accuracy: 0.9023
# Epoch 87/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2300 - categorical_accuracy: 0.9062
# Epoch 88/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1775 - categorical_accuracy: 0.9258
# Epoch 89/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1849 - categorical_accuracy: 0.9336
# Epoch 90/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2488 - categorical_accuracy: 0.9102
# Epoch 91/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2429 - categorical_accuracy: 0.9102
# Epoch 92/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2838 - categorical_accuracy: 0.8867
# Epoch 93/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4454 - categorical_accuracy: 0.8438
# Epoch 94/150
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5547 - categorical_accuracy: 0.8203
# Epoch 95/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.7893 - categorical_accuracy: 0.7617
# Epoch 96/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6571 - categorical_accuracy: 0.7539
# Epoch 97/150
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4699 - categorical_accuracy: 0.8203
# Epoch 98/150
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4512 - categorical_accuracy: 0.7969
# Epoch 99/150
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3115 - categorical_accuracy: 0.8711
# Epoch 100/150
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3141 - categorical_accuracy: 0.8633
# Epoch 101/150
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3390 - categorical_accuracy: 0.8789
# Epoch 102/150
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2785 - categorical_accuracy: 0.8984
# Epoch 103/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1864 - categorical_accuracy: 0.9336
# Epoch 104/150
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1873 - categorical_accuracy: 0.9336
# Epoch 105/150
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1482 - categorical_accuracy: 0.9414
# Epoch 106/150
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2364 - categorical_accuracy: 0.9102
# Epoch 107/150
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5245 - categorical_accuracy: 0.8008
# Epoch 108/150
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3459 - categorical_accuracy: 0.8984
# Epoch 109/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3004 - categorical_accuracy: 0.8984
# Epoch 110/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2295 - categorical_accuracy: 0.9180
# Epoch 111/150
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1164 - categorical_accuracy: 0.9570
# Epoch 112/150
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1125 - categorical_accuracy: 0.9688
# Epoch 113/150
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0990 - categorical_accuracy: 0.9727
# Epoch 114/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1808 - categorical_accuracy: 0.9336
# Epoch 115/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3908 - categorical_accuracy: 0.8555
# Epoch 116/150
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2673 - categorical_accuracy: 0.8750
# Epoch 117/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1589 - categorical_accuracy: 0.9648
# Epoch 118/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1241 - categorical_accuracy: 0.9570
# Epoch 119/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1101 - categorical_accuracy: 0.9570 0s - loss: 0.1165 - categorical_accuracy:
# Epoch 120/150
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0957 - categorical_accuracy: 0.9766
# Epoch 121/150
# 8/8 [==============================] - 0s 43ms/step - loss: 0.0906 - categorical_accuracy: 0.9688
# Epoch 122/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1092 - categorical_accuracy: 0.9609
# Epoch 123/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0973 - categorical_accuracy: 0.9648
# Epoch 124/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1466 - categorical_accuracy: 0.9453
# Epoch 125/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1228 - categorical_accuracy: 0.9570
# Epoch 126/150
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0948 - categorical_accuracy: 0.9727
# Epoch 127/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.0732 - categorical_accuracy: 0.9727
# Epoch 128/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.0524 - categorical_accuracy: 0.9727
# Epoch 129/150
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0961 - categorical_accuracy: 0.9688
# Epoch 130/150
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0745 - categorical_accuracy: 0.9648
# Epoch 131/150
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1199 - categorical_accuracy: 0.9492
# Epoch 132/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0874 - categorical_accuracy: 0.9688
# Epoch 133/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1057 - categorical_accuracy: 0.9570
# Epoch 134/150
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1406 - categorical_accuracy: 0.9375
# Epoch 135/150
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2440 - categorical_accuracy: 0.9102
# Epoch 136/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5246 - categorical_accuracy: 0.8359
# Epoch 137/150
# 8/8 [==============================] - 0s 50ms/step - loss: 1.5380 - categorical_accuracy: 0.6055
# Epoch 138/150
# 8/8 [==============================] - 0s 48ms/step - loss: 1.4006 - categorical_accuracy: 0.5039
# Epoch 139/150
# 8/8 [==============================] - 0s 43ms/step - loss: 1.3232 - categorical_accuracy: 0.5117
# Epoch 140/150
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1669 - categorical_accuracy: 0.5781
# Epoch 141/150
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9635 - categorical_accuracy: 0.6484
# Epoch 142/150
# 8/8 [==============================] - 0s 49ms/step - loss: 1.7871 - categorical_accuracy: 0.5547
# Epoch 143/150
# 8/8 [==============================] - 0s 48ms/step - loss: 1.6579 - categorical_accuracy: 0.3828
# Epoch 144/150
# 8/8 [==============================] - 0s 44ms/step - loss: 1.4350 - categorical_accuracy: 0.5547
# Epoch 145/150
# 8/8 [==============================] - 0s 45ms/step - loss: 1.1287 - categorical_accuracy: 0.5859
# Epoch 146/150
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9378 - categorical_accuracy: 0.6641
# Epoch 147/150
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7654 - categorical_accuracy: 0.7070
# Epoch 148/150
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5918 - categorical_accuracy: 0.7852
# Epoch 149/150
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4512 - categorical_accuracy: 0.8594
# Epoch 150/150
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3878 - categorical_accuracy: 0.8555

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 20, 64)            82688
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 297
# =================================================================
# Total params: 237,449
# Trainable params: 237,449
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'C'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'C'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[13,  0],
#         [ 0,  1]],
#
#        [[11,  0],
#         [ 1,  2]],
#
#        [[13,  0],
#         [ 0,  1]],
#
#        [[11,  1],
#         [ 0,  2]],
#
#        [[12,  0],
#         [ 0,  2]],
#
#        [[12,  0],
#         [ 1,  1]],
#
#        [[12,  1],
#         [ 0,  1]],
#
#        [[11,  1],
#         [ 1,  1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.7857142857142857

# %% [markdown]
# # 11. Test in Real Time

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.7

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-20:]
        
        if len(sequence) == 20:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thank you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# F
